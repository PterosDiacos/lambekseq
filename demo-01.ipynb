# %%
import json
import semcomp as sc
from semgraph import Semgraph
from graphviz import Source
vocab = json.load(open('schema.json'))

# %%
tokens = [
    Semgraph.from_dict(vocab['qnt'], 'every', 1),
    Semgraph.from_dict(vocab['n'], 'boy', 2),
    Semgraph.from_dict(vocab['vt'], 'walked', 3),
    Semgraph.from_dict(vocab['qnt'], 'most', 4),
    Semgraph.from_dict(vocab['n'], 'dogs', 5),
    Semgraph.from_dict(vocab['pv'], 'in', 6),
    Semgraph.from_dict(vocab['qnt'], 'every', 7),
    Semgraph.from_dict(vocab['n'], 'park', 8)
]

# %%
Source(tokens[0].dot_styled)

# %%
Source(tokens[1].dot_styled)

# %%
Source(tokens[2].dot_styled)

# %%
Source(tokens[5].dot_styled)

# %%
H = list(sc.unify('s', tokens))

# %%
len(H)
# Out:
# 8

# %%
Source(H[0].dot_styled)

# %% [markdown]
# boy > dog > park

# %%
Source(H[1].dot_styled)

# %% [markdown]
# dog > park > boy

# %%
Source(H[2].dot_styled)

# %% [markdown]
# BROKEN, see the preposition's location

# %%
Source(H[3].dot_styled)

# %% [markdown]
# park > dog > boy

# %%
Source(H[4].dot_styled)

# %% [markdown]
# park > boy > dog

# %%
Source(H[5].dot_styled)

# %% [markdown]
# dog > boy > park

# %%
Source(H[6].dot_styled)

# %% [markdown]
# BROKEN, see the preposition's location

# %%
Source(H[7].dot_styled)

# %% [markdown]
# boy > park > dog
